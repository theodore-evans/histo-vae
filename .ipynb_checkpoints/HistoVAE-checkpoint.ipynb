# %% [markdown]
# # Generative model for histological FOV data

# %% [markdown]
# Load data

# %%
import pandas as pd
import json
from matplotlib import pyplot as plt

# %%
with open("BreastIHC_APIresponse.json", "r") as f:
    data = json.load(f)

data

# %%
cells = data["response"]["results"]["cells"]
df = pd.DataFrame.from_dict(cells)

# %%
df
# Out:
#       intensity   type     x    y
# 0      0.715734  tumor   241    0
# 1      0.422294  tumor   311    2
# 2      0.339541  tumor   408    0
# 3      0.633990  tumor   487    0
# 4      0.712005  tumor   590    0
# ...         ...    ...   ...  ...
# 1836   0.689424  tumor   904  927
# 1837   0.409558  tumor   975  927
# 1838   0.604563  tumor  1089  927
# 1839   0.406574  tumor   497  928
# 1840   0.391196  tumor   241  928
#
# [1841 rows x 4 columns]

# %%
img = plt.imread("labA_0.722f7db3.png")

plt.imshow(img)
plt.scatter(df.x + 64, df.y + 64, s=2)

fig = plt.gcf()
fig.
